# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import statistics as st

df=pd.read_csv('C:\\Users\HP\Desktop\StudentsPerformance.csv')
np.DataFrame=df
#df=DataFrame(data)
df.rename(columns = {'parental level of education':'parental_level_of_education','test preparation course':'test_preparation_course','math score':'math_score','reading score':'reading_score','writing score':'writing_score'}, inplace = True)

# %%
#Count of male and female candidates

rslt_data_female = df[(df['gender'] == 'female')]
print("No of females "+str(rslt_data_female.count()))
rslt_data_male = df[(df['gender'] == 'male')]
print("No of males "+str(rslt_data_male.count()))
# Out:
# No of females gender                         518
# race/ethnicity                 518
# parental_level_of_education    518
# lunch                          518
# test_preparation_course        518
# math_score                     518
# reading_score                  518
# writing_score                  518
# dtype: int64
# No of males gender                         482
# race/ethnicity                 482
# parental_level_of_education    482
# lunch                          482
# test_preparation_course        482
# math_score                     482
# reading_score                  482
# writing_score                  482
# dtype: int64

# %%
#Parent information regarding their education
rslt_data_parent = df[(df['parental_level_of_education'] == 'high school')]

print("No of high school level "+str(rslt_data_parent.count()))
rslt_data_parent = df[(df['parental_level_of_education'] == 'some college')]

print("No of some college level "+str(rslt_data_parent.count()))
rslt_data_parent = df[(df['parental_level_of_education'] == 'some high school')]

print("some high school level "+str(rslt_data_parent.count()))
rslt_data_parent = df[(df['parental_level_of_education'] == 'some high school')]

print("some high school level "+str(rslt_data_parent.count()))
rslt_data_parent = df[(df['parental_level_of_education'] == "bachelor's degree")]

print("Bachelor degree level "+str(rslt_data_parent.count()))
rslt_data_parent = df[(df['parental_level_of_education'] == "associate's degree")]

print("Associate degree level "+str(rslt_data_parent.count()))
# Out:
# No of high school level gender                         196
# race/ethnicity                 196
# parental_level_of_education    196
# lunch                          196
# test_preparation_course        196
# math_score                     196
# reading_score                  196
# writing_score                  196
# dtype: int64
# No of some college level gender                         226
# race/ethnicity                 226
# parental_level_of_education    226
# lunch                          226
# test_preparation_course        226
# math_score                     226
# reading_score                  226
# writing_score                  226
# dtype: int64
# some high school level gender                         179
# race/ethnicity                 179
# parental_level_of_education    179
# lunch                          179
# test_preparation_course        179
# math_score                     179
# reading_score                  179
# writing_score                  179
# ...

# %%
#Calculate average for math score, reading score and writing score
x=st.mean(df['math_score'])
print("Maths average="+str(x))
x=st.mean(df['reading_score'])
print("Reading score average="+str(x))
x=st.mean(df['writing_score'])
print("Writing score average="+str(x))
# Out:
# Maths average=66.001
# Reading score average=69.195
# Writing score average=68.119

# %%
#statistics for male and female having more than average maths score on the basis of gender
rslt_data_male_avg = df[(df['math_score'] > 66) & (df['gender']=='male')]

print("No of males having more than average math score"+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['math_score'] > 66) & (df['gender']=='female')]

print("No of males having more than average math score"+str(rslt_data_female_avg.count()))
# Out:
# No of males having more than average math scoregender                         276
# race/ethnicity                 276
# parental_level_of_education    276
# lunch                          276
# test_preparation_course        276
# math_score                     276
# reading_score                  276
# writing_score                  276
# dtype: int64
# No of males having more than average math scoregender                         221
# race/ethnicity                 221
# parental_level_of_education    221
# lunch                          221
# test_preparation_course        221
# math_score                     221
# reading_score                  221
# writing_score                  221
# dtype: int64

# %%
#statistics for male and female having more than average reading score on the basis of gender
rslt_data_male_avg = df[(df['reading_score'] > 69) & (df['gender']=='male')]

male=rslt_data_male_avg.count()

print("No of males having more than average reading score "+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['reading_score'] > 69) & (df['gender']=='female')]

print("No of females having more than average reading score"+str(rslt_data_female_avg.count()))
female=rslt_data_female_avg.count()
# Out:
# No of males has gender                         198
# race/ethnicity                 198
# parental_level_of_education    198
# lunch                          198
# test_preparation_course        198
# math_score                     198
# reading_score                  198
# writing_score                  198
# dtype: int64
# No of females has gender                         318
# race/ethnicity                 318
# parental_level_of_education    318
# lunch                          318
# test_preparation_course        318
# math_score                     318
# reading_score                  318
# writing_score                  318
# dtype: int64

# %%
#statistics for male and female having more than average writing score in the basis of gender
rslt_data_male_avg = df[(df['writing_score'] > 68) & (df['gender']=='male')]

male=rslt_data_male_avg.count()

print("No of males having more than average writing score "+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['writing_score'] > 69) & (df['gender']=='female')]

print("No of females having more than average writing score"+str(rslt_data_female_avg.count()))
female=rslt_data_female_avg.count()

# %%
#statistics for male and female having more than average maths score on the basis of test preparation
rslt_data_male_avg = df[(df['math_score'] > 66) & (df['test_preparation_course']=='completed')]

male=rslt_data_male_avg.count()

print("No of males having more than average math score "+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['math_score'] > 66) & (df['test_preparation_course']=='none')]

print("No of females having more than average math score "+str(rslt_data_female_avg.count()))
female=rslt_data_female_avg.count()
# Out:
# gender                         216
# race/ethnicity                 216
# parental_level_of_education    216
# lunch                          216
# test_preparation_course        216
# math_score                     216
# reading_score                  216
# writing_score                  216
# dtype: int64
# No of males has gender                         216
# race/ethnicity                 216
# parental_level_of_education    216
# lunch                          216
# test_preparation_course        216
# math_score                     216
# reading_score                  216
# writing_score                  216
# dtype: int64
# No of females has gender                         281
# race/ethnicity                 281
# parental_level_of_education    281
# lunch                          281
# test_preparation_course        281
# math_score                     281
# reading_score                  281
# writing_score                  281
# dtype: int64
# ...

# %%
#statistics for male and female having more than average reading score on the basis of test preparation
rslt_data_male_avg = df[(df['reading_score'] > 69) & (df['test_preparation_course']=='completed')]

male=rslt_data_male_avg.count()

print("No of males having more than average reading score "+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['reading_score'] > 69) & (df['test_preparation_course']=='none')]

print("No of females having more than average reading score "+str(rslt_data_female_avg.count()))
female=rslt_data_female_avg.count()
# Out:
# gender                         238
# race/ethnicity                 238
# parental_level_of_education    238
# lunch                          238
# test_preparation_course        238
# math_score                     238
# reading_score                  238
# writing_score                  238
# dtype: int64
# No of males has gender                         238
# race/ethnicity                 238
# parental_level_of_education    238
# lunch                          238
# test_preparation_course        238
# math_score                     238
# reading_score                  238
# writing_score                  238
# dtype: int64
# No of females has gender                         278
# race/ethnicity                 278
# parental_level_of_education    278
# lunch                          278
# test_preparation_course        278
# math_score                     278
# reading_score                  278
# writing_score                  278
# dtype: int64
# ...

# %%
#statistics for male and female having more than average writing score on the basis of test preparation
rslt_data_male_avg = df[(df['writing_score'] > 68) & (df['test_preparation_course']=='completed')]

male=rslt_data_male_avg.count()

print("No of males having more than average writing score "+str(rslt_data_male_avg.count()))
rslt_data_female_avg = df[(df['writing_score'] > 68) & (df['test_preparation_course']=='none')]

print("No of females having more than average writing score "+str(rslt_data_female_avg.count()))
female=rslt_data_female_avg.count()
# Out:
# gender                         249
# race/ethnicity                 249
# parental_level_of_education    249
# lunch                          249
# test_preparation_course        249
# math_score                     249
# reading_score                  249
# writing_score                  249
# dtype: int64
# No of males has gender                         249
# race/ethnicity                 249
# parental_level_of_education    249
# lunch                          249
# test_preparation_course        249
# math_score                     249
# reading_score                  249
# writing_score                  249
# dtype: int64
# No of females has gender                         267
# race/ethnicity                 267
# parental_level_of_education    267
# lunch                          267
# test_preparation_course        267
# math_score                     267
# reading_score                  267
# writing_score                  267
# dtype: int64
# ...

# %%
mathmax=df['math_score'].max()
print("maths max mark="+str(mathmax))

mathmin=df['math_score'].min()
print("maths min mark="+str(mathmin))

mathscorevariation=mathmax-mathmin
# on the basis of gender
resmale=df[(df['math_score']==mathmax) | (df['math_score']==mathmin) & (df['gender']=='male')].count()
print("count of males having max variation in math score"+str(resmale))
resfemale=df[(df['math_score']==mathmax) | (df['math_score']==mathmin) & (df['gender']=='female')].count()
print("count of females having max variation in math score"+str(resfemale))
# on the basis of test completed
resmale=df[(df['math_score']==mathmax) | (df['math_score']==mathmin) & (df['test_preparation_course']=='completed')].count()
print("count of males having max variation in math score"+str(resmale))
resfemale=df[(df['math_score']==mathmax) | (df['math_score']==mathmin) & (df['test_preparation_course']=='none')].count()
print("count of females having max variation in math score"+str(resfemale))


#reading score statistics on the basis of gender
readingmax=df['reading_score'].max()
print("max reading score"+str(readingmax))
readingmin=df['reading_score'].min()
print("min reading scorere"+str(readingmin))
readingvariation=readingmax-readingmin

resmale=df[(df['reading_score']==readingmax) | (df['reading_score']==readingmin) & (df['gender']=='male')].count()

print("count of males having max variation in reading score"+str(resmale))
resfemale=df[(df['reading_score']==readingmax) | (df['reading_score']==readingmin) & (df['gender']=='female')].count()
print("count of females having max variation in reading score"+str(resfemale))

#reading score statistics on the basis of test preparation
resmale=df[(df['reading_score']==readingmax) | (df['reading_score']==readingmin) & (df['test_preparation_course']=='completed')].count()
print("count of males having max variation in reading score"+str(resmale))
resfemale=df[(df['reading_score']==readingmax) | (df['reading_score']==readingmin) & (df['test_preparation_course']=='none')].count()
print("count of females having max variation in reading score"+str(resfemale))


writingmax=df['writing_score'].max()

writingmin=df['writing_score'].min()

writingvariation=writingmax-writingmin

#reading score statistics on the basis of gender
resmale=df[(df['writing_score']==writingmax) | (df['writing_score']==writingmin) & (df['gender']=='male')].count()
print("count of males having max variation in writing score"+str(resmale))
resfemale=df[(df['writing_score']==writingmax) | (df['writing_score']==writingmin) & (df['gender']=='female')].count()
print("count of females having max variation in writing score"+str(resfemale))
#reading score statistics on the basis of test preparation
resmale=df[(df['writing_score']==writingmax) | (df['writing_score']==writingmin) & (df['test_preparation_course']=='completed')].count()
print("count of males having max variation in writing score"+str(resmale))
resfemale=df[(df['writing_score']==writingmax) | (df['writing_score']==writingmin) & (df['test_preparation_course']=='none')].count()
print("count of females having max variation in writing score"+str(resfemale))
# Out:
# maths max mark=100
# maths min mark=0
# count of males having max variation in math scoregender                         7
# race/ethnicity                 7
# parental_level_of_education    7
# lunch                          7
# test_preparation_course        7
# math_score                     7
# reading_score                  7
# writing_score                  7
# dtype: int64
# count of females having max variation in math scoregender                         8
# race/ethnicity                 8
# parental_level_of_education    8
# lunch                          8
# test_preparation_course        8
# math_score                     8
# reading_score                  8
# writing_score                  8
# dtype: int64
# count of males having max variation in math scoregender                         7
# race/ethnicity                 7
# parental_level_of_education    7
# lunch                          7
# test_preparation_course        7
# math_score                     7
# ...

# %%
df=pd.read_csv('C:\\Users\HP\Desktop\StudentsPerformance.csv')
df=df.sort_values(by='math score', ascending=False,inplace=True)
#df.head(250)
